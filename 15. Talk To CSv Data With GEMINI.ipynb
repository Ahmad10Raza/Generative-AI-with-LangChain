# %%
# !wget -q https://www.dropbox.com/s/8y6a1zloiscuo5d/black_friday_sales.zip
# !unzip -q black_friday_sales.zip

# %%
import pandas as pd
df=pd.read_csv('train.csv')
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %% [markdown]
# # Creating CSV Agent

# %%
from langchain.agents import create_csv_agent
from langchain_google_genai import ChatGoogleGenerativeAI


llm = ChatGoogleGenerativeAI(model="gemini-pro",
                             temperature=0.7,
                             google_api_key="AIz")

agen=create_csv_agent(llm,'train.csv', verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain.agents import create_csv_agent
#       2 from langchain_google_genai import ChatGoogleGenerativeAI
#       5 llm = ChatGoogleGenerativeAI(model="gemini-pro",
#       6                              temperature=0.7,
#       7                              google_api_key="AIzaSyA0eEk90lLX6AAqIQZmJvgUOv9KOv5o5yM")
#
# File ~/.local/lib/python3.10/site-packages/langchain/agents/__init__.py:92, in __getattr__(name)
#      90     old_path = "langchain." + relative_path
#      91     new_path = "langchain_experimental." + relative_path
# ---> 92     raise ImportError(
#      93         f"{name} has been moved to langchain experimental. "
#      94         "See https://github.com/langchain-ai/langchain/discussions/11680"
#      95         "for more information.\n"
#      96         f"Please update your import statement from: `{old_path}` to `{new_path}`."
#      97     )
#      98 raise AttributeError(f"{name} does not exist")
#
# ImportError: create_csv_agent has been moved to langchain experimental. See https://github.com/langchain-ai/langchain/discussions/11680for more information.
# Please update your import statement from: `langchain.agents.create_csv_agent` to `langchain_experimental.agents.create_csv_agent`.
