# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmad10Raza/Generative-AI-with-LangChain/blob/master/12.%20BabyAGI%20Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BabyAGI?

# %% [markdown]
# 1. **BabyAGI is an AI assistant that adapts to your goals, continuously learns, and creates new tasks to achieve them.** Imagine a helpful friend who not only follows instructions but proactively gets things done and improves over time.
# 2. **It uses cutting-edge technology like OpenAI to understand your needs, analyze results, and even write creative content.** Think of it as a smart assistant with access to powerful tools, constantly generating ideas and insights.
# 3. **Unlike traditional assistants, BabyAGI doesn't just execute pre-defined tasks.** It prioritizes and creates new tasks based on your goals and learns from every interaction, becoming more efficient and helpful the more you use it.
# 4. **Open-source and customizable, BabyAGI lets you tailor it to your specific needs and integrate it with your existing tools.** It's not a black box; you can understand how it works and even change its behavior.
# 5. **While still under development, BabyAGI holds immense potential for diverse applications beyond personal assistance.** Imagine using its adaptive and learning capabilities in business automation, scientific research, or even robot control.
#
# These concise sentences capture the essence of BabyAGI, highlighting its key features, capabilities, and potential, without getting bogged down in technical details.

# %% [markdown]
# **BabyAGI** refers to two related concepts in the world of artificial intelligence:
#
# **1. BabyAGI as an AI Agent:**
#
# - It's an **autonomous AI agent** developed by Yohei Nakajima, designed to automate tasks and achieve objectives through independent planning and execution.
# - It combines cutting-edge technologies like OpenAI, Pinecone, LangChain, and Chroma to:
#     - **Generate tasks:** Based on given objectives and current context.
#     - **Prioritize tasks:** Choose the most suitable actions based on estimated impact and effort.
#     - **Execute tasks:** Utilize various tools and services to complete chosen actions.
#     - **Learn and adapt:** Continuously improve its decision-making through experimentation and feedback.
#
# **2. BabyAGI as an AI System:**
#
# - It can also refer to the **broader ecosystem and research surrounding autonomous AI agents** inspired by the original BabyAGI prototype.
# - This encompasses:
#     - **Theoretical concepts:** Designing and evaluating autonomous AI agents effectively.
#     - **Software libraries and tools:** Open-source implementations for building and deploying your own BabyAGI-like agents.
#     - **Applications and use cases:** Exploring how autonomous agents can be utilized in various domains like personal productivity, business automation, and scientific research.
#
# **Key Benefits of BabyAGI:**
#
# - **Automated Tasks:** Reduces manual effort and saves time by efficiently handling repetitive tasks.
# - **Improved Efficiency:** Optimizes workflows and prioritizes actions for maximizing goal achievement.
# - **Adaptive to Change:** Learns and adapts based on user feedback and changing circumstances.
# - **Flexibility and Customization:** Open-source framework allows for tailored applications and integrations.
#
# **Current Status and Limitations:**
#
# - BabyAGI is still under development, and further research is needed to refine its capabilities and address challenges like reasoning and complex decision-making.
# - Its effectiveness heavily depends on the quality of provided objectives and available tools/services within its environment.
# - Ethical considerations regarding self-learning and autonomous decision-making need careful attention.
#
# **Overall, BabyAGI represents a promising step towards more autonomous and adaptable AI systems, capable of automating tasks and assisting us in achieving our goals. Its open-source nature fosters further development and exploration of the potential for autonomous AI agents in various domains.**

# %% [markdown]
# **Research Paper:** https://yoheinakajima.com/task-driven-autonomous-agent-utilizing-gpt-4-pinecone-and-langchain-for-diverse-applications/

# %% [markdown]
# # How Does BabyAGI Work?

# %%
from IPython.display import Image
Image(filename='Images/BabyAGI.png',width=800, height=800)

# %% [markdown]
# ## BabyAGI's Inner Workings: A Peek into the Brain of an AI Assistant
#
# BabyAGI operates through a continuous loop, cleverly juggling **task execution, result enrichment, creation, and prioritization**. Let's dive into each step:
#
# **1. Task Execution:**
#
# - BabyAGI selects a task from its list, like booking a flight or writing a report.
# - It utilizes different tools and services depending on the task. For example, it might access OpenAI for creative writing or a flight booking API for travel arrangements.
# - It executes the chosen action and records the outcome.
#
# **2. Result Enrichment:**
#
# - BabyAGI doesn't just get things done; it analyzes the results. It leverages the power of OpenAI (or your preferred LLM) to extract further insights and information.
# - This could involve summarizing a lengthy report, identifying key facts from a booked flight confirmation, or generating alternative travel options based on preferences.
#
# **3. Task Creation:**
#
# - Inspired by the enriched results, BabyAGI identifies **new tasks** that contribute to the overall objective.
# - For example, after booking a flight, it might create tasks like packing a suitcase, researching the destination, or setting reminders for check-in.
# - This dynamic task generation allows BabyAGI to adapt and handle complex workflows, going beyond simply executing pre-defined commands.
#
# **4. Task Prioritization:**
#
# - BabyAGI doesn't just blindly create tasks; it prioritizes them based on their estimated impact and effort.
# - It considers urgency, dependencies between tasks, and user preferences to ensure the most efficient path towards achieving the main objective.
# - This intelligent prioritization makes BabyAGI a valuable assistant, helping you focus on the most important tasks first.
#
# **Additional Key Components:**
#
# - **Pinecone:** A vector search platform that efficiently stores and retrieves task-related data, enabling quick task selection and context awareness.
# - **ChromaDB:** A vector store that holds text embeddings, allowing BabyAGI to understand the semantic relationships between tasks and results.
#
# **BabyAGI's strengths lie in its:**
#
# - **Adaptive workflow management:** It dynamically creates and prioritizes tasks, adapting to new information and changes in context.
# - **Continuous learning:** It uses feedback and analysis to improve its decision-making, becoming more efficient over time.
# - **Open-source framework:** It allows for customization and integration with external tools and services.
#
# **Limitations and Ongoing Research:**
#
# - BabyAGI relies heavily on the quality of user-provided objectives and available tools. Clear goals and diverse tools are crucial for optimal performance.
# - Complex reasoning and decision-making under uncertainty remain challenges for all AI systems, including BabyAGI. Research continues to improve its capabilities in these areas.
# - Ethical considerations regarding self-learning and autonomous decision-making require careful attention to ensure responsible AI development.
#
# **Overall, BabyAGI paints a fascinating picture of the future of AI assistants, where machines not only follow instructions but proactively adapt and learn to assist us in achieving our goals in a constantly evolving environment.**

# %% [markdown]
# # Unique Features of BabyAGI?

# %% [markdown]
# BabyAGI shines amidst the crowd of AI assistants with its unique blend of capabilities. Here are some key features that set it apart:
#
# **1. Adaptive Task Management:**
#
# * **Dynamic Task Creation:** Unlike traditional assistants that only execute pre-defined tasks, BabyAGI analyzes results and generates new tasks contributing to the overall goal. Booking a flight triggers tasks like packing and researching the destination, adapting to new information.
# * **Intelligent Prioritization:** It doesn't blindly create tasks; it prioritizes them based on urgency, dependencies, and user preferences, ensuring efficient workflow management.
#
# **2. Continuous Learning and Improvement:**
#
# * **Feedback-Driven Refinement:** BabyAGI learns from feedback and analysis, continuously improving its decision-making. Every completed task and its outcome contribute to its knowledge and future actions.
# * **Evolving Strategies:** BabyAGI doesn't just repeat successful actions; it experiments and evaluates different approaches, becoming more effective over time.
#
# **3. Open-Source and Customizable:**
#
# * **Transparent Framework:** Unlike black-box systems, BabyAGI's inner workings are open-source, allowing for customization and integration with external tools and services. Developers can adapt it to specific needs and environments.
# * **Community Growth:** Open-sourcing fosters collaboration and further development, accelerating advancements in autonomous AI agents like BabyAGI.
#
# **4. Combined Power of Cutting-Edge Technologies:**
#
# * **AI Integration:** BabyAGI leverages the strengths of OpenAI (or your preferred LLM) for creative writing, factual analysis, and enriching results with additional information.
# * **Semantic Understanding:** Utilizing Pinecone and ChromaDB, BabyAGI stores and retrieves context-aware data, enabling efficient task selection and comprehension of relationships between tasks and results.
#
# **5. Potential for Broader Applications:**
#
# * **Beyond Personal Assistant:** BabyAGI's core features hold promise in diverse fields like business automation, scientific research, or even robot control, where adaptive workflows and continuous learning are crucial.
# * **Shaping the Future of AI:** BabyAGI's research and development contribute to the advancement of autonomous AI agents, paving the way for machines that can actively learn, adapt, and collaborate with us in achieving complex goals.
#
# These unique features make BabyAGI more than just an AI assistant; it's a glimpse into the future of intelligent systems that learn, adapt, and work alongside us in an ever-changing world.

# %% [markdown]
# # Pros and Cons of Using BabyAGI?

# %% [markdown]
# ## Weighing the Pros and Cons of BabyAGI: A Decision-Making Guide
#
# Before taking the plunge with BabyAGI, let's analyze its strengths and weaknesses to see if it fits your needs:
#
# **Pros:**
#
# * **Adaptive Task Management:** No more rigid workflows! BabyAGI creates and prioritizes tasks based on context and adapts to new information, saving you time and effort.
# * **Continuous Learning:** It gets smarter with every interaction, improving its decision-making and becoming more efficient over time.
# * **Open-Source and Customizable:** Unlike black-box systems, BabyAGI's code is open, allowing you to tailor it to your specific needs and integrate it with existing tools.
# * **AI Integration:** It leverages the power of cutting-edge LLMs like OpenAI for creative writing, factual analysis, and enriching results with additional insights.
# * **Potential for Diverse Applications:** BabyAGI's core features extend beyond personal assistance, holding promise in fields like business automation, scientific research, and even robot control.
#
# **Cons:**
#
# * **Early Stage Development:** Being under development, BabyAGI might not always make perfect decisions or handle complex tasks flawlessly.
# * **Reliance on User Input:** Clear goals and a diverse pool of available tools are crucial for optimal performance. Vague objectives or limited tools can hinder its effectiveness.
# * **Ethical Considerations:** Self-learning and autonomous decision-making raise ethical concerns that require careful attention and responsible development practices.
# * **Technical Requirements:** Running BabyAGI might require some technical expertise and access to appropriate resources like APIs and computing power.
# * **Limited Availability of Pre-Built Components:** Building custom tools and integrations can be time-consuming and require coding skills.

# %% [markdown]
# # Python Code Implementation With Langchain:

# %%
# !pip install langchain openai tiktoken faiss-cpu google-search-results  -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 794.4/794.4 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 49.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 58.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.4/192.4 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importing Libraries

# %%
import os
from collections import deque
from typing import Dict, List, Optional, Any

from langchain import LLMChain, OpenAI, PromptTemplate
from langchain.embeddings import OpenAIEmbeddings
from langchain.llms import BaseLLM
from langchain.vectorstores.base import VectorStore
from pydantic import BaseModel, Field
from langchain.chains.base import Chain
from langchain.agents import ZeroShotAgent, Tool, AgentExecutor
from langchain import OpenAI, SerpAPIWrapper, LLMChain
from langchain.docstore import InMemoryDocstore
from langchain.vectorstores.faiss import FAISS
import warnings
warnings.filterwarnings("ignore")

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-******"  # https://platform.openai.com (Thx Michael from Twitter)
os.environ['SERPAPI_API_KEY'] = '900***' # https://serpapi.com/

# %%
# Define your embedding model
embeddings_model = OpenAIEmbeddings()
# Initialize the vectorstore as empty
import faiss
embedding_size = 1536
index = faiss.IndexFlatL2(embedding_size)
vectorstore = FAISS(embeddings_model.embed_query, index, InMemoryDocstore({}), {})
# Out:
# WARNING:langchain_community.vectorstores.faiss:`embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %% [markdown]
# ## Define the Chains
#
# BabyAGI relies on three LLM chains:
# - Task creation chain to select new tasks to add to the list
# - Task prioritization chain to re-prioritize tasks
# - Execution Chain to execute the tasks
#
#
# NOTE: in this notebook, the Execution chain will now be an agent.

# %%
class TaskCreationChain(LLMChain):
    """Chain to generates tasks."""

    @classmethod
    def from_llm(cls, llm: BaseLLM, verbose: bool = True) -> LLMChain:
        """Get the response parser."""
        task_creation_template = (
            "You are an task creation AI that uses the result of an execution agent"
            " to create new tasks with the following objective: {objective},"
            " The last completed task has the result: {result}."
            " This result was based on this task description: {task_description}."
            " These are incomplete tasks: {incomplete_tasks}."
            " Based on the result, create new tasks to be completed"
            " by the AI system that do not overlap with incomplete tasks."
            " Return the tasks as an array."
        )
        prompt = PromptTemplate(
            template=task_creation_template,
            input_variables=["result", "task_description", "incomplete_tasks", "objective"],
        )
        return cls(prompt=prompt, llm=llm, verbose=verbose)

# %%
class TaskPrioritizationChain(LLMChain):
    """Chain to prioritize tasks."""

    @classmethod
    def from_llm(cls, llm: BaseLLM, verbose: bool = True) -> LLMChain:
        """Get the response parser."""
        task_prioritization_template = (
            "You are an task prioritization AI tasked with cleaning the formatting of and reprioritizing"
            " the following tasks: {task_names}."
            " Consider the ultimate objective of your team: {objective}."
            " Do not remove any tasks. Return the result as a numbered list, like:"
            " #. First task"
            " #. Second task"
            " Start the task list with number {next_task_id}."
        )
        prompt = PromptTemplate(
            template=task_prioritization_template,
            input_variables=["task_names", "next_task_id", "objective"],
        )
        return cls(prompt=prompt, llm=llm, verbose=verbose)

# %%
todo_prompt = PromptTemplate.from_template("You are a planner who is an expert at coming up with a todo list for a given objective. Come up with a todo list for this objective: {objective}")
todo_chain = LLMChain(llm=OpenAI(temperature=0), prompt=todo_prompt)
search = SerpAPIWrapper()
tools = [
    Tool(
        name = "Search",
        func=search.run,
        description="useful for when you need to answer questions about current events"
    ),
    Tool(
        name = "TODO",
        func=todo_chain.run,
        description="useful for when you need to come up with todo lists. Input: an objective to create a todo list for. Output: a todo list for that objective. Please be very clear what the objective is!"
    )
]


prefix = """You are an AI who performs one task based on the following objective: {objective}. Take into account these previously completed tasks: {context}."""
suffix = """Question: {task}
{agent_scratchpad}"""
prompt = ZeroShotAgent.create_prompt(
    tools,
    prefix=prefix,
    suffix=suffix,
    input_variables=["objective", "task", "context","agent_scratchpad"]
)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Define the BabyAGI Controller
#
# BabyAGI composes the chains defined above in a (potentially-)infinite loop.

# %%
def get_next_task(task_creation_chain: LLMChain, result: Dict, task_description: str, task_list: List[str], objective: str) -> List[Dict]:
    """Get the next task."""
    incomplete_tasks = ", ".join(task_list)
    response = task_creation_chain.run(result=result, task_description=task_description, incomplete_tasks=incomplete_tasks, objective=objective)
    new_tasks = response.split('\n')
    return [{"task_name": task_name} for task_name in new_tasks if task_name.strip()]

# %%
def prioritize_tasks(task_prioritization_chain: LLMChain, this_task_id: int, task_list: List[Dict], objective: str) -> List[Dict]:
    """Prioritize tasks."""
    task_names = [t["task_name"] for t in task_list]
    next_task_id = int(this_task_id) + 1
    response = task_prioritization_chain.run(task_names=task_names, next_task_id=next_task_id, objective=objective)
    new_tasks = response.split('\n')
    prioritized_task_list = []
    for task_string in new_tasks:
        if not task_string.strip():
            continue
        task_parts = task_string.strip().split(".", 1)
        if len(task_parts) == 2:
            task_id = task_parts[0].strip()
            task_name = task_parts[1].strip()
            prioritized_task_list.append({"task_id": task_id, "task_name": task_name})
    return prioritized_task_list

# %%
def _get_top_tasks(vectorstore, query: str, k: int) -> List[str]:
    """Get the top k tasks based on the query."""
    results = vectorstore.similarity_search_with_score(query, k=k)
    if not results:
        return []
    sorted_results, _ = zip(*sorted(results, key=lambda x: x[1], reverse=True))
    return [str(item.metadata['task']) for item in sorted_results]

def execute_task(vectorstore, execution_chain: LLMChain, objective: str, task: str, k: int = 5) -> str:
    """Execute a task."""
    context = _get_top_tasks(vectorstore, query=objective, k=k)
    return execution_chain.run(objective=objective, context=context, task=task)

# %%
class BabyAGI(Chain, BaseModel):
    """Controller model for the BabyAGI agent."""

    task_list: deque = Field(default_factory=deque)
    task_creation_chain: TaskCreationChain = Field(...)
    task_prioritization_chain: TaskPrioritizationChain = Field(...)
    execution_chain: AgentExecutor = Field(...)
    task_id_counter: int = Field(1)
    vectorstore: VectorStore = Field(init=False)
    max_iterations: Optional[int] = None

    class Config:
        """Configuration for this pydantic object."""
        arbitrary_types_allowed = True

    def add_task(self, task: Dict):
        self.task_list.append(task)

    def print_task_list(self):
        print("\033[95m\033[1m" + "\n*****TASK LIST*****\n" + "\033[0m\033[0m")
        for t in self.task_list:
            print(str(t["task_id"]) + ": " + t["task_name"])

    def print_next_task(self, task: Dict):
        print("\033[92m\033[1m" + "\n*****NEXT TASK*****\n" + "\033[0m\033[0m")
        print(str(task["task_id"]) + ": " + task["task_name"])

    def print_task_result(self, result: str):
        print("\033[93m\033[1m" + "\n*****TASK RESULT*****\n" + "\033[0m\033[0m")
        print(result)

    @property
    def input_keys(self) -> List[str]:
        return ["objective"]

    @property
    def output_keys(self) -> List[str]:
        return []

    def _call(self, inputs: Dict[str, Any]) -> Dict[str, Any]:
        """Run the agent."""
        objective = inputs['objective']
        first_task = inputs.get("first_task", "Make a todo list")
        self.add_task({"task_id": 1, "task_name": first_task})
        num_iters = 0
        while True:
            if self.task_list:
                self.print_task_list()

                # Step 1: Pull the first task
                task = self.task_list.popleft()
                self.print_next_task(task)

                # Step 2: Execute the task
                result = execute_task(
                    self.vectorstore, self.execution_chain, objective, task["task_name"]
                )
                this_task_id = int(task["task_id"])
                self.print_task_result(result)

                # Step 3: Store the result in Pinecone
                result_id = f"result_{task['task_id']}"
                self.vectorstore.add_texts(
                    texts=[result],
                    metadatas=[{"task": task["task_name"]}],
                    ids=[result_id],
                )

                # Step 4: Create new tasks and reprioritize task list
                new_tasks = get_next_task(
                    self.task_creation_chain, result, task["task_name"], [t["task_name"] for t in self.task_list], objective
                )
                for new_task in new_tasks:
                    self.task_id_counter += 1
                    new_task.update({"task_id": self.task_id_counter})
                    self.add_task(new_task)
                self.task_list = deque(
                    prioritize_tasks(
                        self.task_prioritization_chain, this_task_id, list(self.task_list), objective
                    )
                )
            num_iters += 1
            if self.max_iterations is not None and num_iters == self.max_iterations:
                print("\033[91m\033[1m" + "\n*****TASK ENDING*****\n" + "\033[0m\033[0m")
                break
        return {}

    @classmethod
    def from_llm(
        cls,
        llm: BaseLLM,
        vectorstore: VectorStore,
        verbose: bool = False,
        **kwargs
    ) -> "BabyAGI":
        """Initialize the BabyAGI Controller."""
        task_creation_chain = TaskCreationChain.from_llm(
            llm, verbose=verbose
        )
        task_prioritization_chain = TaskPrioritizationChain.from_llm(
            llm, verbose=verbose
        )
        llm_chain = LLMChain(llm=llm, prompt=prompt)
        tool_names = [tool.name for tool in tools]
        agent = ZeroShotAgent(llm_chain=llm_chain, allowed_tools=tool_names)
        agent_executor = AgentExecutor.from_agent_and_tools(agent=agent, tools=tools, verbose=True)
        return cls(
            task_creation_chain=task_creation_chain,
            task_prioritization_chain=task_prioritization_chain,
            execution_chain=agent_executor,
            vectorstore=vectorstore,
            **kwargs
        )

# %%
OBJECTIVE = "Be an IPL Cricket Reporter of the most recent match"

# %%
llm = OpenAI(temperature=0)

# %%
# Logging of LLMChains
verbose=False
# If None, will keep on going forever
max_iterations: Optional[int] = 3
baby_agi = BabyAGI.from_llm(
    llm=llm,
    vectorstore=vectorstore,
    verbose=verbose,
    max_iterations=max_iterations
)

# %%
baby_agi({"objective": OBJECTIVE})
# Out:
# *****TASK LIST*****
#
# 1: Make a todo list
#
# *****NEXT TASK*****
#
# 1: Make a todo list
#
#
# > Entering new AgentExecutor chain...
# Thought: I need to create a list of tasks to complete
# Action: TODO
# Action Input: Objective to create a todo list for
# Observation:  a successful job search
#
# 1. Research and identify potential job opportunities in your desired field or industry.
# 2. Update and tailor your resume and cover letter to fit each job application.
# 3. Network and reach out to contacts in your industry for potential job leads or referrals.
# 4. Utilize online job search engines and company websites to search for job openings.
# 5. Attend job fairs and career events to connect with potential employers.
# 6. Prepare for interviews by researching the company, practicing common interview questions, and dressing professionally.
# 7. Follow up with employers after interviews to express your interest and inquire about next steps.
# ...

# %% [markdown]
# **Due To Charge Of OpenAI API Key Error Occur**

# %% [markdown]
# # Reference:
# 0. Yohei Nakajima : https://yoheinakajima.com/task-driven-autonomous-agent-utilizing-gpt-4-pinecone-and-langchain-for-diverse-applications/
# 1. Sam Witteveen: https://www.youtube.com/watch?v=DRgPyOXZ-oE
# 2. 1littlecoder : https://www.youtube.com/watch?v=WosPGHPObx8
# 3. bard.google.com

# %% [markdown]
# # **Thank You!**
